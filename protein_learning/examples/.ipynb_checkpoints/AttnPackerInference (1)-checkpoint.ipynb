# %%
import os
import sys
code_root = os.path.dirname(os.path.dirname(os.getcwd()))
if code_root not in sys.path:
    sys.path.append(code_root)
print(code_root)
# Out:
# /Users/matthewmcpartlon/VSCode/AttnPacker

# %%
import torch
from typing import Optional, Union
from torch import Tensor

import protein_learning.models.model_abc.train as sc
from protein_learning.models.utils.model_io import (
    load_n_save_args,
    print_args,
    get_args_n_groups,
    load_args_for_eval,
)
from protein_learning.models.fbb_design.train import Train as SCPTrain, _augment
from protein_learning.common.data.datasets.utils import set_canonical_coords_n_masks
from protein_learning.common.data.data_types.protein import Protein
import protein_learning.common.protein_constants as pc
from protein_learning.features.input_embedding import InputEmbedding
from protein_learning.models.utils.dataset_augment_fns import impute_cb
from protein_learning.common.data.data_types.model_input import ModelInput



def exists(x):
    return x is not None


def default(x, y):
    return x if exists(x) else y


def _parse_args(arg_stream):
    args = []
    for x in arg_stream:  # noqa
        line = x.strip()
        if len(line.strip()) > 0 and not line.startswith("#"):
            arg = line.split(" ")
            for a in arg:
                args.append(a)
    return args


def parse_args(arg_path=None, arg_list=None, arg_string=None):
    if exists(arg_list):
        return arg_list
    elif exists(arg_path):
        with open(arg_path, "r") as f:
            return _parse_args(f)
    elif exists(arg_string):
        return _parse_args(arg_string.split("\n"))
    else:
        raise Exception("All inputs are None!")
        
def make_predicted_protein(model_out, seq: Optional[Union[str,Tensor]] = None) -> Protein:
    """Constructs predicted protein"""
    if torch.is_tensor(seq):
        seq = "".join([pc.INDEX_TO_AA_ONE[x.item()] for x in seq.squeeze()])
    coords = model_out.predicted_coords.squeeze(0)
    pred_protein = model_out.decoy_protein.from_coords_n_seq(coords,seq)
    pred_protein = set_canonical_coords_n_masks(pred_protein, overwrite=True)
    return pred_protein
        
        
INFERENCE_ARGS = """
# whether todesign sequence
--mask_seq
# Don't mask any residues in input sequence
--no_mask_weight 1
--inter_no_mask_weight 1
--no_predict_from_angles
"""


class Inference:
    def __init__(
        self, 
        model_n_config_root: str,
        use_design_model: bool = True,
        verbose=True,
    ):
        if use_design_model:
            model_name = 'fbb_design_21_12_2022_16:07:51'
        else:
            model_name = 'fbb_design_21_12_2022_15:58:28'
        self.model_name = model_name
        self.use_design_model = use_design_model
        self.verbose = verbose
        self.trainer = SCPTrain(skip_init=True)
        self.resource_root = model_n_config_root
        self.load_inference_args()
        self.trainer.pad_embeddings = self.args.mask_seq or self.args.mask_feats
        self.trainer._setup()

    def load_inference_args(self): 
        eval_parser = sc.get_default_parser_for_eval()
        self.trainer.add_extra_cmd_line_options_for_eval(eval_parser)
        # default inference args
        arg_list = parse_args(arg_string=INFERENCE_ARGS)
        eval_args, eval_groups = get_args_n_groups(eval_parser, arg_list)
        self.trainer.eval_args = eval_args
        self.trainer.eval_groups = eval_groups

        train_parser = self.trainer.add_extra_cmd_line_options(sc.get_default_parser())
        train_args, train_groups = get_args_n_groups(train_parser, ["none"])  # defaults only

        global_override = sc.default_global_override_for_eval(eval_args)
        global_override.update(self.trainer.global_override_eval)  # args that should always be overridden
        rr = self.resource_root
        config, args, arg_groups = load_args_for_eval(
            global_config_path=os.path.join(rr,"params",f"{self.model_name}.npy"),
            model_config_path=os.path.join(rr,"params",f"{self.model_name}_fbb_design.npy"),
            model_override=self.trainer.model_override_eval,
            global_override=global_override,
            default_model_args=train_args,
            default_model_arg_groups=train_groups,
        )

        if self.verbose:
            print(f"global override\n {global_override}")
            print(f"model override\n {self.trainer.model_override_eval}")
        self.config, self.args, self.arg_groups = config, args, arg_groups
        self.trainer.config = config
        self.trainer.args=args
        self.trainer.arg_groups=arg_groups
        
        return config, args, arg_groups
    
    def _init_model(self):
        # set up feature generator
        feature_config = sc.get_input_feature_config(
            self.arg_groups,
            pad_embeddings=self.trainer.pad_embeddings,
            extra_pair_feat_dim=self.trainer.extra_pair_feat_dim,
            extra_res_feat_dim=self.trainer.extra_res_feat_dim,
        )
        self.feature_config = feature_config  # noqa
        feat_gen = sc.get_feature_gen(
            self.arg_groups, feature_config, apply_masks=self.trainer.apply_masks
        )
        self.feat_gen = feat_gen  # noqa
        self.input_embedding = InputEmbedding(feature_config)
        self.model = self.trainer.get_model(self.input_embedding)
    
    def get_model(self):
        self._init_model()
        model_path = os.path.join(self.resource_root,"models",f"{self.model_name}.tar")
        checkpoint = torch.load(model_path, map_location="cpu")
        self.model.load_state_dict(checkpoint['model'])#strict=False)
        return self.model
    
    def load_example(
        self,
        pdb_path,
        fasta_path = None,
        seq_mask = None
    ):
        if exists(seq_mask):
            assert self.use_design_model
            
        protein = Protein.FromPDBAndSeq(
            pdb_path = pdb_path,
            seq=fasta_path,
            atom_tys = pc.ALL_ATOMS,
            missing_seq = fasta_path is None,
            load_ss=False,
        )
        protein, _ = impute_cb(protein,protein)
        extra = _augment(protein, protein)
        protein = set_canonical_coords_n_masks(protein)
        
        return ModelInput(
            decoy=protein,
            native=protein,
            input_features=self.feat_gen.generate_features(
                protein,
                extra=extra,
                seq_mask=seq_mask,
            ),
            extra=extra,
        )
# Out:
# /Users/matthewmcpartlon/miniconda3/envs/py38/lib/python3.8/site-packages/Bio/SubsMat/__init__.py:126: BiopythonDeprecationWarning: Bio.SubsMat has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.substitution_matrices as a replacement, and contact the Biopython developers if you still need the Bio.SubsMat module.
#   warnings.warn(

# %%
RESOURCE_ROOT = "/Users/matthewmcpartlon/Downloads/AttnPackerPTM"
runner = Inference(RESOURCE_ROOT, verbose=False, use_design_model=False)
model = runner.get_model()
device = "cuda:0" if torch.cuda.is_available() else "cpu"
model = model.to(device).eval()
# Out:
# usage: ipykernel_launcher.py [-h] [--raise_exceptions]
#                              [--model_config_path MODEL_CONFIG_PATH]
#                              [--global_config_path GLOBAL_CONFIG_PATH]
#                              [--stats_dir STATS_DIR] [--pdb_dir PDB_DIR]
#                              [--gpu_indices GPU_INDICES [GPU_INDICES ...]]
#                              [--eval_decoy_folder EVAL_DECOY_FOLDER]
#                              [--eval_native_folder EVAL_NATIVE_FOLDER]
#                              [--eval_target_list EVAL_TARGET_LIST]
#                              [--eval_seq_folder EVAL_SEQ_FOLDER]
#                              [--max_samples MAX_SAMPLES]
#                              [--n_replicas N_REPLICAS]
#                              [--model_path MODEL_PATH] [--max_len MAX_LEN]
#                              [--get_nsr_stats] [--get_lddt_stats]
#                              [--get_violation_stats] [--get_rmsd_stats]
#                              [--get_contact_stats] [--get_mae_stats]
#                              [--get_distance_stats] [--mask_feats]
#                              [--mask_seq]
#                              [--mask_feat_n_seq_indep_prob MASK_FEAT_N_SEQ_INDEP_PROB]
#                              [--spatial_mask_weight SPATIAL_MASK_WEIGHT]
#                              [--contiguous_mask_weight CONTIGUOUS_MASK_WEIGHT]
#                              [--random_mask_weight RANDOM_MASK_WEIGHT]
#                              [--no_mask_weight NO_MASK_WEIGHT]
#                              [--full_mask_weight FULL_MASK_WEIGHT]
#                              [--cdr_mask_weight CDR_MASK_WEIGHT]
#                              [--interface_full_mask_weight INTERFACE_FULL_MASK_WEIGHT]
#                              [--true_interface_mask_weight TRUE_INTERFACE_MASK_WEIGHT]
#                              [--true_inverse_interface_mask_weight TRUE_INVERSE_INTERFACE_MASK_WEIGHT]
#                              [--interface_mask_weight INTERFACE_MASK_WEIGHT]
#                              [--inverse_interface_mask_weight INVERSE_INTERFACE_MASK_WEIGHT]
#                              [--inverse_interface_full_mask_weight INVERSE_INTERFACE_FULL_MASK_WEIGHT]
#                              [--spatial_mask_top_k SPATIAL_MASK_TOP_K]
#                              [--spatial_mask_max_radius SPATIAL_MASK_MAX_RADIUS]
#                              [--contiguous_mask_min_len CONTIGUOUS_MASK_MIN_LEN]
#                              [--contiguous_mask_max_len CONTIGUOUS_MASK_MAX_LEN]
#                              [--random_mask_min_p RANDOM_MASK_MIN_P]
#                              [--random_mask_max_p RANDOM_MASK_MAX_P]
#                              [--max_mask_frac MAX_MASK_FRAC]
#                              [--min_mask_frac MIN_MASK_FRAC]
#                              [--interface_mask_min_frac INTERFACE_MASK_MIN_FRAC]
#                              [--interface_mask_max_frac INTERFACE_MASK_MAX_FRAC]
#                              [--inverse_interface_mask_min_frac INVERSE_INTERFACE_MASK_MIN_FRAC]
#                              [--inverse_interface_mask_max_frac INVERSE_INTERFACE_MASK_MAX_FRAC]
#                              [--inter_random_mask_weight INTER_RANDOM_MASK_WEIGHT]
#                              [--inter_one_to_all_mask_weight INTER_ONE_TO_ALL_MASK_WEIGHT]
#                              [--inter_full_mask_weight INTER_FULL_MASK_WEIGHT]
#                              [--inter_no_mask_weight INTER_NO_MASK_WEIGHT]
#                              [--linear_partition_weight LINEAR_PARTITION_WEIGHT]
#                              [--bilinear_partition_weight BILINEAR_PARTITION_WEIGHT]
#                              [--identity_partition_weight IDENTITY_PARTITION_WEIGHT]
#                              [--linear_n_classes LINEAR_N_CLASSES [LINEAR_N_CLASSES ...]]
#                              [--partition_min_frac PARTITION_MIN_FRAC]
#                              [--partition_min_len PARTITION_MIN_LEN]
#                              [--bilinear_max_len BILINEAR_MAX_LEN]
#                              [--use_cycles USE_CYCLES] [--partition_chains]
#                              [--train_on_bounded_complex]
#                              [--min_len_cutoff MIN_LEN_CUTOFF]
#                              [--use_esm_prob USE_ESM_PROB]
#                              [--use_esm_both_chain_prob USE_ESM_BOTH_CHAIN_PROB]
#                              [--esm_gpu_idx ESM_GPU_IDX]
#                              [--include_contact_prob INCLUDE_CONTACT_PROB]
#                              [--include_interface_prob INCLUDE_INTERFACE_PROB]
#                              [--contact_fracs CONTACT_FRACS [CONTACT_FRACS ...]]
#                              [--interface_fracs INTERFACE_FRACS [INTERFACE_FRACS ...]]
#                              [--include_both_interface_prob INCLUDE_BOTH_INTERFACE_PROB]
#                              [--num_interface NUM_INTERFACE]
#                              [--num_contact NUM_CONTACT]
#                              [--random_interface RANDOM_INTERFACE]
#                              [--random_contact RANDOM_CONTACT]
# ipykernel_launcher.py: error: unrecognized arguments: --no_predict_from_angles
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /Users/matthewmcpartlon/miniconda3/envs/py38/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %% [markdown]
# # Run Inference

# %%
import time
pdb_path = "./pdbs/T1043.pdb"
design_mask = None
mask_frac = 0
if runner.use_design_model:
    design_mask = torch.rand(79)>(1-mask_frac) #mask out 50% of residue identities at random
example = runner.load_example(pdb_path = pdb_path, seq_mask = design_mask)

# %%
start = time.time()
with torch.no_grad():
    model_out = model.forward(example.to(device), use_cycles = 1)
    print(f"Ran inference in {round(time.time() - start,3)} seconds")
# Out:
# Ran inference in 3.45 seconds

# %% [markdown]
# ## Gather Model Output

# %%
#masked residue positions
seq_mask = default(
    example.input_features.seq_mask,torch.zeros(len(example.decoy)).bool()
)

# coords, pLDDT, and Sequence
res_feats = model_out.scalar_output
pred_coords = model_out.predicted_coords
pred_seq_labels = model_out.decoy_protein.seq_encoding
pred_seq_logits = None


# Predicted pLDDT
plddt_head = model.loss_fn.loss_fns["plddt"]
pred_plddt = plddt_head.get_expected_value(res_feats)
pred_plddt = pred_plddt

# Predicted Sequence
if "nsr" in model.loss_fn and torch.any(seq_mask):
    pred_seq_logits = model.loss_fn.loss_fns["nsr"].get_predicted_logits(res_feats)
    pred_seq_labels = torch.argmax(pred_seq_logits,dim=-1)

out = pred_coords, pred_seq_labels, pred_seq_logits, pred_plddt
fn = lambda x : x.detach().cpu().squeeze() if torch.is_tensor(x) else x
pred_coords, pred_seq_labels, pred_seq_logits, pred_plddt = map(fn,out)

# %% [markdown]
# ## Write prediction to pdb

# %%
pred_protein = make_predicted_protein(model_out, seq = pred_seq_labels)
pdb_out_path = f"./attn_packer/examples/{pred_protein.name}_packed.pdb"
print(f"saving pdb to {pdb_out_path}")
pred_protein.to_pdb(pdb_out_path)
# Out:
# saving pdb to ./attn_packer/examples/T1043_packed.pdb

# %% [markdown]
# ## Apply Post-Processing Procedure to Prediction

# %%
from protein_learning.protein_utils.sidechains.project_sidechains import project_onto_rotamers

pp_pdb_out_path = f"./attn_packer/examples/{pred_protein.name}_packed_pp.pdb"

projected_coords, _ = project_onto_rotamers(
    atom_coords = pred_protein.atom_coords.unsqueeze(0),
    sequence = pred_protein.seq_encoding.unsqueeze(0),
    atom_mask = pred_protein.atom_masks.unsqueeze(0),
    steric_clash_weight=[0.5],
)

pred_protein.to_pdb(pp_pdb_out_path, coords=projected_coords.squeeze())
# Out:
# [fn: project_onto_rotamers] : Using device cpu
# [INFO] Beginning rotamer projection
# [INFO] Initial loss values
#    [RMSD loss] = 0.031
#    [Steric loss] = 15.745
#    [Angle Dev. loss] = 0.0
#
# beginning iter: 0, steric weight: 0.5
# beginning iter: 1, steric weight: 0.5
# [INFO] Final Loss Values
#    [RMSD loss] = nan
#    [Steric loss] = 0.0
#    [Angle Dev. loss] = nan

# %% [markdown]
# ## Check out packing with NGL Viewer

# %% [markdown]
# ### Before Post-Process

# %%
import nglview as nv
view = nv.show_file(pdb_out_path)
view.add_cartoon("protein",color_scheme='residue_index')
view.add_ball_and_stick("protein")
view

# %% [markdown]
# ### After Post-Process

# %%
import nglview as nv
view = nv.show_file(pp_pdb_out_path)
view.add_cartoon("protein",color_scheme='residue_index')
view.add_ball_and_stick("protein")
view

# %% [markdown]
# ## Examine Predicted pLDDT

# %%
import matplotlib.pyplot as plt
plt.plot(torch.arange(pred_plddt.numel()),pred_plddt.squeeze())

# %% [markdown]
# ## Examine Predicted Sequences (If Doing Sequence Design)

# %%
pred_protein = make_predicted_protein(model_out, seq = pred_seq_labels)
x,y = model_out.decoy_protein.seq, pred_protein.seq

print("Input Sequence :\n",x)
print("Predicted Sequence :\n",y)
aln="".join(["|" if x[i]!=y[i] else " " for i in range(len(x))])
masked="".join(["*" if seq_mask[i] else " " for i in range(len(x))])
print("Aligned:")
print(f" {x}\n {aln}\n {y}\n {masked}")

# %%
model_out.__dict__

# %%
# ^^ angles are being predicted

# %%
[k for k in model.__dict__]
# Out:
# ['training',
#  '_parameters',
#  '_buffers',
#  '_non_persistent_buffers_set',
#  '_backward_hooks',
#  '_is_full_backward_hook',
#  '_forward_hooks',
#  '_forward_pre_hooks',
#  '_state_dict_hooks',
#  '_load_state_dict_pre_hooks',
#  '_load_state_dict_post_hooks',
#  '_modules',
#  'node_in',
#  'pair_in',
#  'project_in',
#  'device_indices',
#  'secondary_device',
#  'main_device',
#  'n_dist_bins_for_recycle',
#  'n_cycles',
#  'use_cycles',
#  'torsion_loss_weight',
#  'use_tfn',
#  'node_dim_in',
#  'pair_dim_in',
#  'predict_from_angles',
#  'pre_structure_pair',
#  'pre_structure_node']

# %%
model.predict_from_angles
# Out:
# True

# %%
for name, par in model.named_parameters():
    print(name)
# Out:
# model.attn_layers.0.attn_block.attn.self_bias
# model.attn_layers.0.attn_block.attn.null_bias
# model.attn_layers.0.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.0.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.0.attn_block.attn.null_keys.0
# model.attn_layers.0.attn_block.attn.null_keys.1
# model.attn_layers.0.attn_block.attn.null_values.0
# model.attn_layers.0.attn_block.attn.null_values.1
# model.attn_layers.0.attn_block.attn.to_bias.weight
# model.attn_layers.0.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.0.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.0.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.0.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.0.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.0.attn_block.prenorm.norms.0.scale
# model.attn_layers.0.attn_block.prenorm.norms.0.bias
# model.attn_layers.0.attn_block.prenorm.norms.1.scale
# model.attn_layers.0.attn_block.prenorm.norms.1.bias
# model.attn_layers.0.attn_block.residual.alpha
# model.attn_layers.0.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.0.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.0.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.0.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.0.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.0.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.0.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.0.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.0.ff_residual.residual.alpha
# model.attn_layers.0.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.0.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.0.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.0.ff_residual.pre_norm.norms.1.bias
# model.attn_layers.1.attn_block.attn.self_bias
# model.attn_layers.1.attn_block.attn.null_bias
# model.attn_layers.1.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.1.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.1.attn_block.attn.null_keys.0
# model.attn_layers.1.attn_block.attn.null_keys.1
# model.attn_layers.1.attn_block.attn.null_values.0
# model.attn_layers.1.attn_block.attn.null_values.1
# model.attn_layers.1.attn_block.attn.to_bias.weight
# model.attn_layers.1.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.1.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.1.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.1.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.1.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.1.attn_block.prenorm.norms.0.scale
# model.attn_layers.1.attn_block.prenorm.norms.0.bias
# model.attn_layers.1.attn_block.prenorm.norms.1.scale
# model.attn_layers.1.attn_block.prenorm.norms.1.bias
# model.attn_layers.1.attn_block.residual.alpha
# model.attn_layers.1.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.1.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.1.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.1.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.1.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.1.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.1.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.1.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.1.ff_residual.residual.alpha
# model.attn_layers.1.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.1.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.1.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.1.ff_residual.pre_norm.norms.1.bias
# model.attn_layers.2.attn_block.attn.self_bias
# model.attn_layers.2.attn_block.attn.null_bias
# model.attn_layers.2.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.2.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.2.attn_block.attn.null_keys.0
# model.attn_layers.2.attn_block.attn.null_keys.1
# model.attn_layers.2.attn_block.attn.null_values.0
# model.attn_layers.2.attn_block.attn.null_values.1
# model.attn_layers.2.attn_block.attn.to_bias.weight
# model.attn_layers.2.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.2.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.2.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.2.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.2.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.2.attn_block.prenorm.norms.0.scale
# model.attn_layers.2.attn_block.prenorm.norms.0.bias
# model.attn_layers.2.attn_block.prenorm.norms.1.scale
# model.attn_layers.2.attn_block.prenorm.norms.1.bias
# model.attn_layers.2.attn_block.residual.alpha
# model.attn_layers.2.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.2.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.2.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.2.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.2.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.2.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.2.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.2.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.2.ff_residual.residual.alpha
# model.attn_layers.2.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.2.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.2.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.2.ff_residual.pre_norm.norms.1.bias
# model.attn_layers.3.attn_block.attn.self_bias
# model.attn_layers.3.attn_block.attn.null_bias
# model.attn_layers.3.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.3.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.3.attn_block.attn.null_keys.0
# model.attn_layers.3.attn_block.attn.null_keys.1
# model.attn_layers.3.attn_block.attn.null_values.0
# model.attn_layers.3.attn_block.attn.null_values.1
# model.attn_layers.3.attn_block.attn.to_bias.weight
# model.attn_layers.3.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.3.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.3.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.3.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.3.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.3.attn_block.prenorm.norms.0.scale
# model.attn_layers.3.attn_block.prenorm.norms.0.bias
# model.attn_layers.3.attn_block.prenorm.norms.1.scale
# model.attn_layers.3.attn_block.prenorm.norms.1.bias
# model.attn_layers.3.attn_block.residual.alpha
# model.attn_layers.3.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.3.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.3.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.3.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.3.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.3.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.3.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.3.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.3.ff_residual.residual.alpha
# model.attn_layers.3.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.3.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.3.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.3.ff_residual.pre_norm.norms.1.bias
# model.attn_layers.4.attn_block.attn.self_bias
# model.attn_layers.4.attn_block.attn.null_bias
# model.attn_layers.4.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.4.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.4.attn_block.attn.null_keys.0
# model.attn_layers.4.attn_block.attn.null_keys.1
# model.attn_layers.4.attn_block.attn.null_values.0
# model.attn_layers.4.attn_block.attn.null_values.1
# model.attn_layers.4.attn_block.attn.to_bias.weight
# model.attn_layers.4.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.4.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.4.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.4.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.4.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.4.attn_block.prenorm.norms.0.scale
# model.attn_layers.4.attn_block.prenorm.norms.0.bias
# model.attn_layers.4.attn_block.prenorm.norms.1.scale
# model.attn_layers.4.attn_block.prenorm.norms.1.bias
# model.attn_layers.4.attn_block.residual.alpha
# model.attn_layers.4.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.4.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.4.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.4.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.4.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.4.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.4.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.4.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.4.ff_residual.residual.alpha
# model.attn_layers.4.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.4.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.4.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.4.ff_residual.pre_norm.norms.1.bias
# model.attn_layers.5.attn_block.attn.self_bias
# model.attn_layers.5.attn_block.attn.null_bias
# model.attn_layers.5.attn_block.attn.to_self_kv.0.weight
# model.attn_layers.5.attn_block.attn.to_self_kv.1.weight
# model.attn_layers.5.attn_block.attn.null_keys.0
# model.attn_layers.5.attn_block.attn.null_keys.1
# model.attn_layers.5.attn_block.attn.null_values.0
# model.attn_layers.5.attn_block.attn.null_values.1
# model.attn_layers.5.attn_block.attn.to_bias.weight
# model.attn_layers.5.attn_block.attn.to_out.projs.0.weight
# model.attn_layers.5.attn_block.attn.to_out.projs.1.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.0.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.1.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.4.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.5.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,0).rp.net.8.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.0.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.1.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.4.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.5.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(0,1).rp.net.8.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.0.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.1.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.4.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.5.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,0).rp.net.8.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.0.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.1.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.4.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.5.bias
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.weight
# model.attn_layers.5.attn_block.attn.to_kv.kernel_unary.(1,1).rp.net.8.bias
# model.attn_layers.5.attn_block.attn.to_q.projs.0.weight
# model.attn_layers.5.attn_block.attn.to_q.projs.1.weight
# model.attn_layers.5.attn_block.prenorm.norms.0.scale
# model.attn_layers.5.attn_block.prenorm.norms.0.bias
# model.attn_layers.5.attn_block.prenorm.norms.1.scale
# model.attn_layers.5.attn_block.prenorm.norms.1.bias
# model.attn_layers.5.attn_block.residual.alpha
# model.attn_layers.5.ff_residual.ff.layers.0.0.projs.0.weight
# model.attn_layers.5.ff_residual.ff.layers.0.0.projs.1.weight
# model.attn_layers.5.ff_residual.ff.layers.0.1.norms.0.scale
# model.attn_layers.5.ff_residual.ff.layers.0.1.norms.0.bias
# model.attn_layers.5.ff_residual.ff.layers.0.1.norms.1.scale
# model.attn_layers.5.ff_residual.ff.layers.0.1.norms.1.bias
# model.attn_layers.5.ff_residual.ff.layers.1.0.projs.0.weight
# model.attn_layers.5.ff_residual.ff.layers.1.0.projs.1.weight
# model.attn_layers.5.ff_residual.residual.alpha
# model.attn_layers.5.ff_residual.pre_norm.norms.0.scale
# model.attn_layers.5.ff_residual.pre_norm.norms.0.bias
# model.attn_layers.5.ff_residual.pre_norm.norms.1.scale
# model.attn_layers.5.ff_residual.pre_norm.norms.1.bias
# model.edge_norm.weight
# model.edge_norm.bias
# model.conv_in.kernel_unary.(0,0).rp.net.0.weight
# model.conv_in.kernel_unary.(0,0).rp.net.0.bias
# model.conv_in.kernel_unary.(0,0).rp.net.1.weight
# model.conv_in.kernel_unary.(0,0).rp.net.1.bias
# model.conv_in.kernel_unary.(0,0).rp.net.4.weight
# model.conv_in.kernel_unary.(0,0).rp.net.4.bias
# model.conv_in.kernel_unary.(0,0).rp.net.5.weight
# model.conv_in.kernel_unary.(0,0).rp.net.5.bias
# model.conv_in.kernel_unary.(0,0).rp.net.8.weight
# model.conv_in.kernel_unary.(0,0).rp.net.8.bias
# model.conv_in.kernel_unary.(0,1).rp.net.0.weight
# model.conv_in.kernel_unary.(0,1).rp.net.0.bias
# model.conv_in.kernel_unary.(0,1).rp.net.1.weight
# model.conv_in.kernel_unary.(0,1).rp.net.1.bias
# model.conv_in.kernel_unary.(0,1).rp.net.4.weight
# model.conv_in.kernel_unary.(0,1).rp.net.4.bias
# model.conv_in.kernel_unary.(0,1).rp.net.5.weight
# model.conv_in.kernel_unary.(0,1).rp.net.5.bias
# model.conv_in.kernel_unary.(0,1).rp.net.8.weight
# model.conv_in.kernel_unary.(0,1).rp.net.8.bias
# model.conv_in.kernel_unary.(1,0).rp.net.0.weight
# model.conv_in.kernel_unary.(1,0).rp.net.0.bias
# model.conv_in.kernel_unary.(1,0).rp.net.1.weight
# model.conv_in.kernel_unary.(1,0).rp.net.1.bias
# model.conv_in.kernel_unary.(1,0).rp.net.4.weight
# model.conv_in.kernel_unary.(1,0).rp.net.4.bias
# model.conv_in.kernel_unary.(1,0).rp.net.5.weight
# model.conv_in.kernel_unary.(1,0).rp.net.5.bias
# model.conv_in.kernel_unary.(1,0).rp.net.8.weight
# model.conv_in.kernel_unary.(1,0).rp.net.8.bias
# model.conv_in.kernel_unary.(1,1).rp.net.0.weight
# model.conv_in.kernel_unary.(1,1).rp.net.0.bias
# model.conv_in.kernel_unary.(1,1).rp.net.1.weight
# model.conv_in.kernel_unary.(1,1).rp.net.1.bias
# model.conv_in.kernel_unary.(1,1).rp.net.4.weight
# model.conv_in.kernel_unary.(1,1).rp.net.4.bias
# model.conv_in.kernel_unary.(1,1).rp.net.5.weight
# model.conv_in.kernel_unary.(1,1).rp.net.5.bias
# model.conv_in.kernel_unary.(1,1).rp.net.8.weight
# model.conv_in.kernel_unary.(1,1).rp.net.8.bias
# model.conv_in.self_interact.projs.0.weight
# model.conv_in.self_interact.projs.1.weight
# model.conv_in.self_interact_sum.alpha
# model.conv_in_pre_norm.norms.0.scale
# model.conv_in_pre_norm.norms.0.bias
# model.conv_in_pre_norm.norms.1.scale
# model.conv_in_pre_norm.norms.1.bias
# model.conv_out_pre_norm.norms.0.scale
# model.conv_out_pre_norm.norms.0.bias
# model.conv_out_pre_norm.norms.1.scale
# model.conv_out_pre_norm.norms.1.bias
# model.conv_out.kernel_unary.(0,0).rp.net.0.weight
# model.conv_out.kernel_unary.(0,0).rp.net.0.bias
# model.conv_out.kernel_unary.(0,0).rp.net.1.weight
# model.conv_out.kernel_unary.(0,0).rp.net.1.bias
# model.conv_out.kernel_unary.(0,0).rp.net.4.weight
# model.conv_out.kernel_unary.(0,0).rp.net.4.bias
# model.conv_out.kernel_unary.(0,0).rp.net.5.weight
# model.conv_out.kernel_unary.(0,0).rp.net.5.bias
# model.conv_out.kernel_unary.(0,0).rp.net.8.weight
# model.conv_out.kernel_unary.(0,0).rp.net.8.bias
# model.conv_out.kernel_unary.(0,1).rp.net.0.weight
# model.conv_out.kernel_unary.(0,1).rp.net.0.bias
# model.conv_out.kernel_unary.(0,1).rp.net.1.weight
# model.conv_out.kernel_unary.(0,1).rp.net.1.bias
# model.conv_out.kernel_unary.(0,1).rp.net.4.weight
# model.conv_out.kernel_unary.(0,1).rp.net.4.bias
# model.conv_out.kernel_unary.(0,1).rp.net.5.weight
# model.conv_out.kernel_unary.(0,1).rp.net.5.bias
# model.conv_out.kernel_unary.(0,1).rp.net.8.weight
# model.conv_out.kernel_unary.(0,1).rp.net.8.bias
# model.conv_out.kernel_unary.(1,0).rp.net.0.weight
# model.conv_out.kernel_unary.(1,0).rp.net.0.bias
# model.conv_out.kernel_unary.(1,0).rp.net.1.weight
# model.conv_out.kernel_unary.(1,0).rp.net.1.bias
# model.conv_out.kernel_unary.(1,0).rp.net.4.weight
# model.conv_out.kernel_unary.(1,0).rp.net.4.bias
# model.conv_out.kernel_unary.(1,0).rp.net.5.weight
# model.conv_out.kernel_unary.(1,0).rp.net.5.bias
# model.conv_out.kernel_unary.(1,0).rp.net.8.weight
# model.conv_out.kernel_unary.(1,0).rp.net.8.bias
# model.conv_out.kernel_unary.(1,1).rp.net.0.weight
# model.conv_out.kernel_unary.(1,1).rp.net.0.bias
# model.conv_out.kernel_unary.(1,1).rp.net.1.weight
# model.conv_out.kernel_unary.(1,1).rp.net.1.bias
# model.conv_out.kernel_unary.(1,1).rp.net.4.weight
# model.conv_out.kernel_unary.(1,1).rp.net.4.bias
# model.conv_out.kernel_unary.(1,1).rp.net.5.weight
# model.conv_out.kernel_unary.(1,1).rp.net.5.bias
# model.conv_out.kernel_unary.(1,1).rp.net.8.weight
# model.conv_out.kernel_unary.(1,1).rp.net.8.bias
# model.conv_out.self_interact.projs.0.weight
# model.conv_out.self_interact.projs.1.weight
# model.conv_out.self_interact_sum.alpha
# model.out_proj.0.norms.0.scale
# model.out_proj.0.norms.0.bias
# model.out_proj.0.norms.1.scale
# model.out_proj.0.norms.1.bias
# model.out_proj.1.projs.0.weight
# model.out_proj.1.projs.1.weight
# input_embedding.pair_embeddings.joint_pair_n_sep.rel_sep.embedding.weight
# input_embedding.pair_embeddings.joint_pair_n_sep.res_ty_a.embedding.weight
# input_embedding.pair_embeddings.joint_pair_n_sep.res_ty_b.embedding.weight
# residue_project_in.weight
# residue_project_in.bias
# pair_project_in.weight
# pair_project_in.bias
# loss_fn.loss_fns.pair-dist.net.0.weight
# loss_fn.loss_fns.pair-dist.net.0.bias
# loss_fn.loss_fns.pair-dist.net.1.weight
# loss_fn.loss_fns.pair-dist.net.1.bias
# loss_fn.loss_fns.pair-dist.net.3.weight
# loss_fn.loss_fns.pair-dist.net.3.bias
# loss_fn.loss_fns.plddt.net.0.weight
# loss_fn.loss_fns.plddt.net.0.bias
# loss_fn.loss_fns.plddt.net.1.weight
# loss_fn.loss_fns.plddt.net.1.bias
# loss_fn.loss_fns.plddt.net.3.weight
# loss_fn.loss_fns.plddt.net.3.bias
# pre_structure.node_updates.0.attn.to_qkv.weight
# pre_structure.node_updates.0.attn.to_g.weight
# pre_structure.node_updates.0.attn.to_g.bias
# pre_structure.node_updates.0.attn.to_out_node.weight
# pre_structure.node_updates.0.attn.to_out_node.bias
# pre_structure.node_updates.0.attn.node_norm.weight
# pre_structure.node_updates.0.attn.node_norm.bias
# pre_structure.node_updates.0.attn.to_bias.weight
# pre_structure.node_updates.0.attn.pair_norm.weight
# pre_structure.node_updates.0.attn.pair_norm.bias
# pre_structure.node_updates.0.attn_residual.alpha
# pre_structure.node_updates.0.transition.net.0.weight
# pre_structure.node_updates.0.transition.net.0.bias
# pre_structure.node_updates.0.transition.net.1.proj.weight
# pre_structure.node_updates.0.transition.net.4.weight
# pre_structure.node_updates.0.transition_residual.alpha
# pre_structure.node_updates.1.attn.to_qkv.weight
# pre_structure.node_updates.1.attn.to_g.weight
# pre_structure.node_updates.1.attn.to_g.bias
# pre_structure.node_updates.1.attn.to_out_node.weight
# pre_structure.node_updates.1.attn.to_out_node.bias
# pre_structure.node_updates.1.attn.node_norm.weight
# pre_structure.node_updates.1.attn.node_norm.bias
# pre_structure.node_updates.1.attn.to_bias.weight
# pre_structure.node_updates.1.attn.pair_norm.weight
# pre_structure.node_updates.1.attn.pair_norm.bias
# pre_structure.node_updates.1.attn_residual.alpha
# pre_structure.node_updates.1.transition.net.0.weight
# pre_structure.node_updates.1.transition.net.0.bias
# pre_structure.node_updates.1.transition.net.1.proj.weight
# pre_structure.node_updates.1.transition.net.4.weight
# pre_structure.node_updates.1.transition_residual.alpha
# pre_structure.node_updates.2.attn.to_qkv.weight
# pre_structure.node_updates.2.attn.to_g.weight
# pre_structure.node_updates.2.attn.to_g.bias
# pre_structure.node_updates.2.attn.to_out_node.weight
# pre_structure.node_updates.2.attn.to_out_node.bias
# pre_structure.node_updates.2.attn.node_norm.weight
# pre_structure.node_updates.2.attn.node_norm.bias
# pre_structure.node_updates.2.attn.to_bias.weight
# pre_structure.node_updates.2.attn.pair_norm.weight
# pre_structure.node_updates.2.attn.pair_norm.bias
# pre_structure.node_updates.2.attn_residual.alpha
# pre_structure.node_updates.2.transition.net.0.weight
# pre_structure.node_updates.2.transition.net.0.bias
# pre_structure.node_updates.2.transition.net.1.proj.weight
# pre_structure.node_updates.2.transition.net.4.weight
# pre_structure.node_updates.2.transition_residual.alpha
# pre_structure.node_updates.3.attn.to_qkv.weight
# pre_structure.node_updates.3.attn.to_g.weight
# pre_structure.node_updates.3.attn.to_g.bias
# pre_structure.node_updates.3.attn.to_out_node.weight
# pre_structure.node_updates.3.attn.to_out_node.bias
# pre_structure.node_updates.3.attn.node_norm.weight
# pre_structure.node_updates.3.attn.node_norm.bias
# pre_structure.node_updates.3.attn.to_bias.weight
# pre_structure.node_updates.3.attn.pair_norm.weight
# pre_structure.node_updates.3.attn.pair_norm.bias
# pre_structure.node_updates.3.attn_residual.alpha
# pre_structure.node_updates.3.transition.net.0.weight
# pre_structure.node_updates.3.transition.net.0.bias
# pre_structure.node_updates.3.transition.net.1.proj.weight
# pre_structure.node_updates.3.transition.net.4.weight
# pre_structure.node_updates.3.transition_residual.alpha
# pre_structure.node_updates.4.attn.to_qkv.weight
# pre_structure.node_updates.4.attn.to_g.weight
# pre_structure.node_updates.4.attn.to_g.bias
# pre_structure.node_updates.4.attn.to_out_node.weight
# pre_structure.node_updates.4.attn.to_out_node.bias
# pre_structure.node_updates.4.attn.node_norm.weight
# pre_structure.node_updates.4.attn.node_norm.bias
# pre_structure.node_updates.4.attn.to_bias.weight
# pre_structure.node_updates.4.attn.pair_norm.weight
# pre_structure.node_updates.4.attn.pair_norm.bias
# pre_structure.node_updates.4.attn_residual.alpha
# pre_structure.node_updates.4.transition.net.0.weight
# pre_structure.node_updates.4.transition.net.0.bias
# pre_structure.node_updates.4.transition.net.1.proj.weight
# pre_structure.node_updates.4.transition.net.4.weight
# pre_structure.node_updates.4.transition_residual.alpha
# pre_structure.node_updates.5.attn.to_qkv.weight
# pre_structure.node_updates.5.attn.to_g.weight
# pre_structure.node_updates.5.attn.to_g.bias
# pre_structure.node_updates.5.attn.to_out_node.weight
# pre_structure.node_updates.5.attn.to_out_node.bias
# pre_structure.node_updates.5.attn.node_norm.weight
# pre_structure.node_updates.5.attn.node_norm.bias
# pre_structure.node_updates.5.attn.to_bias.weight
# pre_structure.node_updates.5.attn.pair_norm.weight
# pre_structure.node_updates.5.attn.pair_norm.bias
# pre_structure.node_updates.5.attn_residual.alpha
# pre_structure.node_updates.5.transition.net.0.weight
# pre_structure.node_updates.5.transition.net.0.bias
# pre_structure.node_updates.5.transition.net.1.proj.weight
# pre_structure.node_updates.5.transition.net.4.weight
# pre_structure.node_updates.5.transition_residual.alpha
# pre_structure.pair_updates.0.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.0.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.0.layers.0.0.project_in.weight
# pre_structure.pair_updates.0.layers.0.0.project_in.bias
# pre_structure.pair_updates.0.layers.0.0.project_out.weight
# pre_structure.pair_updates.0.layers.0.0.project_out.bias
# pre_structure.pair_updates.0.layers.0.1.residual.alpha
# pre_structure.pair_updates.0.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.0.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.0.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.0.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.0.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.0.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.0.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.0.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.0.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.0.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.0.layers.1.1.residual.alpha
# pre_structure.pair_updates.0.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.0.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.0.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.0.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.0.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.0.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.0.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.0.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.0.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.0.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.0.layers.2.1.residual.alpha
# pre_structure.pair_updates.0.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.0.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.0.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.0.layers.3.0.to_b.weight
# pre_structure.pair_updates.0.layers.3.0.to_g.weight
# pre_structure.pair_updates.0.layers.3.0.to_g.bias
# pre_structure.pair_updates.0.layers.3.0.to_out.weight
# pre_structure.pair_updates.0.layers.3.0.to_out.bias
# pre_structure.pair_updates.0.layers.3.1.residual.alpha
# pre_structure.pair_updates.0.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.0.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.0.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.0.layers.4.0.to_b.weight
# pre_structure.pair_updates.0.layers.4.0.to_g.weight
# pre_structure.pair_updates.0.layers.4.0.to_g.bias
# pre_structure.pair_updates.0.layers.4.0.to_out.weight
# pre_structure.pair_updates.0.layers.4.0.to_out.bias
# pre_structure.pair_updates.0.layers.4.1.residual.alpha
# pre_structure.pair_updates.0.transition.net.0.weight
# pre_structure.pair_updates.0.transition.net.0.bias
# pre_structure.pair_updates.0.transition.net.1.proj.weight
# pre_structure.pair_updates.0.transition.net.4.weight
# pre_structure.pair_updates.0.transition.residual.residual.alpha
# pre_structure.pair_updates.1.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.1.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.1.layers.0.0.project_in.weight
# pre_structure.pair_updates.1.layers.0.0.project_in.bias
# pre_structure.pair_updates.1.layers.0.0.project_out.weight
# pre_structure.pair_updates.1.layers.0.0.project_out.bias
# pre_structure.pair_updates.1.layers.0.1.residual.alpha
# pre_structure.pair_updates.1.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.1.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.1.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.1.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.1.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.1.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.1.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.1.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.1.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.1.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.1.layers.1.1.residual.alpha
# pre_structure.pair_updates.1.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.1.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.1.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.1.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.1.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.1.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.1.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.1.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.1.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.1.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.1.layers.2.1.residual.alpha
# pre_structure.pair_updates.1.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.1.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.1.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.1.layers.3.0.to_b.weight
# pre_structure.pair_updates.1.layers.3.0.to_g.weight
# pre_structure.pair_updates.1.layers.3.0.to_g.bias
# pre_structure.pair_updates.1.layers.3.0.to_out.weight
# pre_structure.pair_updates.1.layers.3.0.to_out.bias
# pre_structure.pair_updates.1.layers.3.1.residual.alpha
# pre_structure.pair_updates.1.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.1.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.1.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.1.layers.4.0.to_b.weight
# pre_structure.pair_updates.1.layers.4.0.to_g.weight
# pre_structure.pair_updates.1.layers.4.0.to_g.bias
# pre_structure.pair_updates.1.layers.4.0.to_out.weight
# pre_structure.pair_updates.1.layers.4.0.to_out.bias
# pre_structure.pair_updates.1.layers.4.1.residual.alpha
# pre_structure.pair_updates.1.transition.net.0.weight
# pre_structure.pair_updates.1.transition.net.0.bias
# pre_structure.pair_updates.1.transition.net.1.proj.weight
# pre_structure.pair_updates.1.transition.net.4.weight
# pre_structure.pair_updates.1.transition.residual.residual.alpha
# pre_structure.pair_updates.2.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.2.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.2.layers.0.0.project_in.weight
# pre_structure.pair_updates.2.layers.0.0.project_in.bias
# pre_structure.pair_updates.2.layers.0.0.project_out.weight
# pre_structure.pair_updates.2.layers.0.0.project_out.bias
# pre_structure.pair_updates.2.layers.0.1.residual.alpha
# pre_structure.pair_updates.2.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.2.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.2.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.2.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.2.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.2.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.2.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.2.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.2.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.2.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.2.layers.1.1.residual.alpha
# pre_structure.pair_updates.2.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.2.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.2.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.2.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.2.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.2.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.2.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.2.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.2.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.2.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.2.layers.2.1.residual.alpha
# pre_structure.pair_updates.2.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.2.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.2.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.2.layers.3.0.to_b.weight
# pre_structure.pair_updates.2.layers.3.0.to_g.weight
# pre_structure.pair_updates.2.layers.3.0.to_g.bias
# pre_structure.pair_updates.2.layers.3.0.to_out.weight
# pre_structure.pair_updates.2.layers.3.0.to_out.bias
# pre_structure.pair_updates.2.layers.3.1.residual.alpha
# pre_structure.pair_updates.2.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.2.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.2.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.2.layers.4.0.to_b.weight
# pre_structure.pair_updates.2.layers.4.0.to_g.weight
# pre_structure.pair_updates.2.layers.4.0.to_g.bias
# pre_structure.pair_updates.2.layers.4.0.to_out.weight
# pre_structure.pair_updates.2.layers.4.0.to_out.bias
# pre_structure.pair_updates.2.layers.4.1.residual.alpha
# pre_structure.pair_updates.2.transition.net.0.weight
# pre_structure.pair_updates.2.transition.net.0.bias
# pre_structure.pair_updates.2.transition.net.1.proj.weight
# pre_structure.pair_updates.2.transition.net.4.weight
# pre_structure.pair_updates.2.transition.residual.residual.alpha
# pre_structure.pair_updates.3.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.3.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.3.layers.0.0.project_in.weight
# pre_structure.pair_updates.3.layers.0.0.project_in.bias
# pre_structure.pair_updates.3.layers.0.0.project_out.weight
# pre_structure.pair_updates.3.layers.0.0.project_out.bias
# pre_structure.pair_updates.3.layers.0.1.residual.alpha
# pre_structure.pair_updates.3.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.3.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.3.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.3.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.3.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.3.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.3.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.3.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.3.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.3.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.3.layers.1.1.residual.alpha
# pre_structure.pair_updates.3.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.3.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.3.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.3.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.3.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.3.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.3.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.3.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.3.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.3.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.3.layers.2.1.residual.alpha
# pre_structure.pair_updates.3.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.3.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.3.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.3.layers.3.0.to_b.weight
# pre_structure.pair_updates.3.layers.3.0.to_g.weight
# pre_structure.pair_updates.3.layers.3.0.to_g.bias
# pre_structure.pair_updates.3.layers.3.0.to_out.weight
# pre_structure.pair_updates.3.layers.3.0.to_out.bias
# pre_structure.pair_updates.3.layers.3.1.residual.alpha
# pre_structure.pair_updates.3.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.3.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.3.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.3.layers.4.0.to_b.weight
# pre_structure.pair_updates.3.layers.4.0.to_g.weight
# pre_structure.pair_updates.3.layers.4.0.to_g.bias
# pre_structure.pair_updates.3.layers.4.0.to_out.weight
# pre_structure.pair_updates.3.layers.4.0.to_out.bias
# pre_structure.pair_updates.3.layers.4.1.residual.alpha
# pre_structure.pair_updates.3.transition.net.0.weight
# pre_structure.pair_updates.3.transition.net.0.bias
# pre_structure.pair_updates.3.transition.net.1.proj.weight
# pre_structure.pair_updates.3.transition.net.4.weight
# pre_structure.pair_updates.3.transition.residual.residual.alpha
# pre_structure.pair_updates.4.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.4.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.4.layers.0.0.project_in.weight
# pre_structure.pair_updates.4.layers.0.0.project_in.bias
# pre_structure.pair_updates.4.layers.0.0.project_out.weight
# pre_structure.pair_updates.4.layers.0.0.project_out.bias
# pre_structure.pair_updates.4.layers.0.1.residual.alpha
# pre_structure.pair_updates.4.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.4.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.4.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.4.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.4.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.4.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.4.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.4.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.4.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.4.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.4.layers.1.1.residual.alpha
# pre_structure.pair_updates.4.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.4.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.4.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.4.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.4.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.4.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.4.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.4.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.4.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.4.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.4.layers.2.1.residual.alpha
# pre_structure.pair_updates.4.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.4.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.4.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.4.layers.3.0.to_b.weight
# pre_structure.pair_updates.4.layers.3.0.to_g.weight
# pre_structure.pair_updates.4.layers.3.0.to_g.bias
# pre_structure.pair_updates.4.layers.3.0.to_out.weight
# pre_structure.pair_updates.4.layers.3.0.to_out.bias
# pre_structure.pair_updates.4.layers.3.1.residual.alpha
# pre_structure.pair_updates.4.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.4.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.4.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.4.layers.4.0.to_b.weight
# pre_structure.pair_updates.4.layers.4.0.to_g.weight
# pre_structure.pair_updates.4.layers.4.0.to_g.bias
# pre_structure.pair_updates.4.layers.4.0.to_out.weight
# pre_structure.pair_updates.4.layers.4.0.to_out.bias
# pre_structure.pair_updates.4.layers.4.1.residual.alpha
# pre_structure.pair_updates.4.transition.net.0.weight
# pre_structure.pair_updates.4.transition.net.0.bias
# pre_structure.pair_updates.4.transition.net.1.proj.weight
# pre_structure.pair_updates.4.transition.net.4.weight
# pre_structure.pair_updates.4.transition.residual.residual.alpha
# pre_structure.pair_updates.5.layers.0.0.pre_norm.weight
# pre_structure.pair_updates.5.layers.0.0.pre_norm.bias
# pre_structure.pair_updates.5.layers.0.0.project_in.weight
# pre_structure.pair_updates.5.layers.0.0.project_in.bias
# pre_structure.pair_updates.5.layers.0.0.project_out.weight
# pre_structure.pair_updates.5.layers.0.0.project_out.bias
# pre_structure.pair_updates.5.layers.0.1.residual.alpha
# pre_structure.pair_updates.5.layers.1.0.pre_norm.weight
# pre_structure.pair_updates.5.layers.1.0.pre_norm.bias
# pre_structure.pair_updates.5.layers.1.0.to_feats_n_gates.weight
# pre_structure.pair_updates.5.layers.1.0.to_feats_n_gates.bias
# pre_structure.pair_updates.5.layers.1.0.gate_out_proj.weight
# pre_structure.pair_updates.5.layers.1.0.gate_out_proj.bias
# pre_structure.pair_updates.5.layers.1.0.to_out.0.weight
# pre_structure.pair_updates.5.layers.1.0.to_out.0.bias
# pre_structure.pair_updates.5.layers.1.0.to_out.1.weight
# pre_structure.pair_updates.5.layers.1.0.to_out.1.bias
# pre_structure.pair_updates.5.layers.1.1.residual.alpha
# pre_structure.pair_updates.5.layers.2.0.pre_norm.weight
# pre_structure.pair_updates.5.layers.2.0.pre_norm.bias
# pre_structure.pair_updates.5.layers.2.0.to_feats_n_gates.weight
# pre_structure.pair_updates.5.layers.2.0.to_feats_n_gates.bias
# pre_structure.pair_updates.5.layers.2.0.gate_out_proj.weight
# pre_structure.pair_updates.5.layers.2.0.gate_out_proj.bias
# pre_structure.pair_updates.5.layers.2.0.to_out.0.weight
# pre_structure.pair_updates.5.layers.2.0.to_out.0.bias
# pre_structure.pair_updates.5.layers.2.0.to_out.1.weight
# pre_structure.pair_updates.5.layers.2.0.to_out.1.bias
# pre_structure.pair_updates.5.layers.2.1.residual.alpha
# pre_structure.pair_updates.5.layers.3.0.pre_norm.weight
# pre_structure.pair_updates.5.layers.3.0.pre_norm.bias
# pre_structure.pair_updates.5.layers.3.0.to_qkv.weight
# pre_structure.pair_updates.5.layers.3.0.to_b.weight
# pre_structure.pair_updates.5.layers.3.0.to_g.weight
# pre_structure.pair_updates.5.layers.3.0.to_g.bias
# pre_structure.pair_updates.5.layers.3.0.to_out.weight
# pre_structure.pair_updates.5.layers.3.0.to_out.bias
# pre_structure.pair_updates.5.layers.3.1.residual.alpha
# pre_structure.pair_updates.5.layers.4.0.pre_norm.weight
# pre_structure.pair_updates.5.layers.4.0.pre_norm.bias
# pre_structure.pair_updates.5.layers.4.0.to_qkv.weight
# pre_structure.pair_updates.5.layers.4.0.to_b.weight
# pre_structure.pair_updates.5.layers.4.0.to_g.weight
# pre_structure.pair_updates.5.layers.4.0.to_g.bias
# pre_structure.pair_updates.5.layers.4.0.to_out.weight
# pre_structure.pair_updates.5.layers.4.0.to_out.bias
# pre_structure.pair_updates.5.layers.4.1.residual.alpha
# pre_structure.pair_updates.5.transition.net.0.weight
# pre_structure.pair_updates.5.transition.net.0.bias
# pre_structure.pair_updates.5.transition.net.1.proj.weight
# pre_structure.pair_updates.5.transition.net.4.weight
# pre_structure.pair_updates.5.transition.residual.residual.alpha
# pair_norm.weight
# pair_norm.bias
# to_structure_node.0.weight
# to_structure_node.0.bias
# to_structure_node.1.weight
# to_structure_node.1.bias
# to_structure_pair.0.weight
# to_structure_pair.0.bias
# to_structure_pair.1.weight
# to_structure_pair.1.bias
# to_points_norm_pre.weight
# to_points_norm_pre.bias
# to_points_norm_post.weight
# to_points_norm_post.bias
# to_out_node.0.weight
# to_out_node.0.bias
# to_out_node.1.weight
# to_out_node.1.bias
# to_points.angle_resnet.linear_in.weight
# to_points.angle_resnet.linear_in.bias
# to_points.angle_resnet.linear_initial.weight
# to_points.angle_resnet.linear_initial.bias
# to_points.angle_resnet.layers.0.linear_1.weight
# to_points.angle_resnet.layers.0.linear_1.bias
# to_points.angle_resnet.layers.0.linear_2.weight
# to_points.angle_resnet.layers.0.linear_2.bias
# to_points.angle_resnet.layers.1.linear_1.weight
# to_points.angle_resnet.layers.1.linear_1.bias
# to_points.angle_resnet.layers.1.linear_2.weight
# to_points.angle_resnet.layers.1.linear_2.bias
# to_points.angle_resnet.linear_out.weight
# to_points.angle_resnet.linear_out.bias

# %%
runner.args.predict_from_angles
# Out:
# True
